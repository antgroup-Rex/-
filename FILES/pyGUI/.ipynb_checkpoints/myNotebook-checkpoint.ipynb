# %%
# run AUI_MAIN.py
from AUI_GlobalImports import *

# %%
# whos

# %%
appDataObj  = appDB.myAppData()
appDataObj.initializeDataFields()
print appDataObj.lastPastedText
# Out:
# selfInitTest1

# %%
# run data_handlers/AppGlobalData.py

# %%
fileDict1 = files_handler.get_file_details(u'C:/Users/Ran_the_User/Documents/GitHub\pyFiles\FILES\pyGUI/quad_sim.csv')
filePath = 'C:\Users\Ran_the_User\Documents\RAN\python\pandastable-master\pandastable\datasets/'
fileDict2 = files_handler.get_file_details(u'C:/Users\Ran_the_User\Documents\RAN\python\pandastable-master\pandastable\datasets/titanic3.csv')
fileDict3 = files_handler.get_file_details(u'C:/Users\Ran_the_User\Documents\RAN\python\pandastable-master\pandastable\datasets/tips.csv')
files_handler.load_CSV_to_appData(fileDict1, appDataObj)
files_handler.load_CSV_to_appData(fileDict2, appDataObj)
files_handler.load_CSV_to_appData(fileDict3, appDataObj)
# Out:
# {'extension': u'.csv', 'absPath': u'C:\\Users\\Ran_the_User\\Documents\\GitHub\\pyFiles\\FILES\\pyGUI', 'originalGivenName': u'C:/Users/Ran_the_User/Documents/GitHub\\pyFiles\\FILES\\pyGUI/quad_sim.csv', 'isFile': True, 'basename': u'quad_sim', 'relPath': ''}
#
# {'extension': u'.csv', 'absPath': u'C:\\Users\\Ran_the_User\\Documents\\RAN\\python\\pandastable-master\\pandastable\\datasets', 'originalGivenName': u'C:/Users\\Ran_the_User\\Documents\\RAN\\python\\pandastable-master\\pandastable\\datasets/titanic3.csv', 'isFile': True, 'basename': u'titanic3', 'relPath': ''}
#
# {'extension': u'.csv', 'absPath': u'C:\\Users\\Ran_the_User\\Documents\\RAN\\python\\pandastable-master\\pandastable\\datasets', 'originalGivenName': u'C:/Users\\Ran_the_User\\Documents\\RAN\\python\\pandastable-master\\pandastable\\datasets/tips.csv', 'isFile': True, 'basename': u'tips', 'relPath': ''}
#
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
# ...

# %%
loadedFiles = appDataObj.mainDict

# %%
for ndx, itm in enumerate(loadedFiles):
    print ndx
    print itm.Name
# Out:
# 0
# C:/Users/Ran_the_User/Documents/GitHub\pyFiles\FILES\pyGUI/quad_sim.csv
# 1
# C:/Users\Ran_the_User\Documents\RAN\python\pandastable-master\pandastable\datasets/titanic3.csv
# 2
# C:/Users\Ran_the_User\Documents\RAN\python\pandastable-master\pandastable\datasets/tips.csv

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-e7fa32cb05ba> in <module>()
# ----> 1 path
#
# NameError: name 'path' is not defined

# %%
run C:\Users\Ran_the_User\Documents\GitHub\pyFiles\FILES\pyGUI\data_handlers/DataFrames_actions.py
# Out:
#  script name : __main__
# {'index': [1, 2, 3, 4], 'stamData': ['ran', 'child', 0, 3]}
#    index stamData
# 0      1      ran
# 1      2    child
# 2      3        0
# 3      4        3
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# C:\Users\Ran_the_User\Documents\GitHub\pyFiles\FILES\pyGUI\data_handlers\DataFrames_actions.py in <module>()
#      31
#      32     #bigger data
# ---> 33     testDF = pd.read_csv('df_data_example.csv')
#      34
#      35     print get_head(testDF)
#
# ...

# %%
a = testDF.head()
b = testDF.tail()
print a
print a.append(b)
# print b.append(a)  #upside
# Out:
#        a    b             c         d             e         f         g
# 0  0.000  0.0  0.000000e+00  0.000000  0.000000e+00  0.000000  0.000000
# 1  0.000  2.0  0.000000e+00 -2.024525  0.000000e+00  0.000000  0.000000
# 2  0.005  2.0 -1.729841e-10 -2.024525  1.014131e-14 -0.000001 -0.000582
# 3  0.010  2.0 -9.320964e-10 -2.024525  2.310650e-14 -0.000006 -0.001163
# 4  0.015  2.0 -3.303355e-09 -2.024525  1.181756e-12 -0.000013 -0.001745
#             a         b             c         d             e           f  \
# 0       0.000  0.000000  0.000000e+00  0.000000  0.000000e+00    0.000000
# 1       0.000  2.000000  0.000000e+00 -2.024525  0.000000e+00    0.000000
# 2       0.005  2.000000 -1.729841e-10 -2.024525  1.014131e-14   -0.000001
# 3       0.010  2.000000 -9.320964e-10 -2.024525  2.310650e-14   -0.000006
# 4       0.015  2.000000 -3.303355e-09 -2.024525  1.181756e-12   -0.000013
# 9997   49.980 -0.062897 -1.827636e+00  1.335614  2.615382e+00  409.881013
# ...

# %%
c= testDF.get_values()
print c
c= list(testDF)  # get header. maybe find a better not questionable formula ??
print c
# Out:
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   2.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  5.00000000e-03   2.00000000e+00  -1.72984061e-10 ...,   1.01413091e-14
#    -1.45392723e-06  -5.81570967e-04]
#  ...,
#  [  4.99900000e+01  -8.09521181e-02  -1.78315357e+00 ...,   2.58817724e+00
#     4.10051295e+02   1.70120435e+01]
#  [  4.99950000e+01  -8.98111827e-02  -1.76041204e+00 ...,   2.57473701e+00
#     4.10136315e+02   1.69958282e+01]
#  [  5.00000000e+01  -9.85555898e-02  -1.73728013e+00 ...,   2.56138942e+00
#     4.10221253e+02   1.69797566e+01]]
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
testDF.head(-1)
# Out:
#             a         b             c         d             e           f  \
# 0       0.000  0.000000  0.000000e+00  0.000000  0.000000e+00    0.000000
# 1       0.000  2.000000  0.000000e+00 -2.024525  0.000000e+00    0.000000
# 2       0.005  2.000000 -1.729841e-10 -2.024525  1.014131e-14   -0.000001
# 3       0.010  2.000000 -9.320964e-10 -2.024525  2.310650e-14   -0.000006
# 4       0.015  2.000000 -3.303355e-09 -2.024525  1.181756e-12   -0.000013
# 5       0.020  2.000000 -7.526471e-09 -2.024525  5.472975e-12   -0.000023
# 6       0.025  2.000000 -1.447548e-08 -2.024525  1.683659e-11   -0.000036
# 7       0.030  2.000000 -2.495842e-08 -2.024525  3.812882e-11   -0.000052
# 8       0.035  2.000000 -3.969726e-08 -2.024525  7.744680e-11   -0.000071
# 9       0.040  2.000000 -5.931418e-08 -2.024525  1.489612e-10   -0.000093
# 10      0.045  2.000000 -8.450617e-08 -2.024525  2.622893e-10   -0.000118
# 11      0.050  2.000000 -1.159718e-07 -2.024525  4.341473e-10   -0.000146
# ...
